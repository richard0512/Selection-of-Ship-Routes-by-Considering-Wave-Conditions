# %%
import ship
import RAW
import Coordinate
import pandas as pd
import WaveData
import Vs_decision
import voyage
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

jalur_pelayaran = 'Jalur Pelayaran.xlsx'
data_set_gelombang = '04 Januari 2023.xlsx'
data_kapal = 'Data Kapal Kriso KCS.xlsx'
start_date_time = '26-10-2022 00:00:00'
start_time = 10

# %%
ship.particular(data_kapal)[1]
# Out:
#    Ship Particular                Value
# 0        Ship Name            Kriso KCS
# 1        Ship Type            Container
# 2        Dimension                  NaN
# 3     Displacement             4902.545
# 4              LWL                232.5
# 5              LPP                  230
# 6          Breadth                 32.2
# 7           Depth                    19
# 8            Draft                 10.8
# 9           Speed                    15
# 10              CB                0.651
# 11              CM                0.985
# 12     Engine Type                    0
# 13    Engine Power                 1880
# 14            SFOC                  175
# 15    Engine Speed  Medium speed engine

# %%
route = Coordinate.distance_route(jalur_pelayaran)
route
# Out:
#        coordinate    Lat1     Lng1    Lat2     Lng2  Distance (nm)
# 0    coordinate 0  -7.203  112.728  -4.611  116.204        259.111
# 1    coordinate 1  -4.611  116.204  -0.814  118.635        269.590
# 2    coordinate 2  -0.814  118.635   2.372  121.715        265.409
# 3    coordinate 3   2.372  121.715   5.081  125.398        273.803
# 4    coordinate 4   5.081  125.398   8.996  127.586        267.740
# 5    coordinate 5   8.996  127.586  13.232  129.281        272.076
# 6    coordinate 6  13.232  129.281  17.497  131.054        274.721
# 7    coordinate 7  17.497  131.054  21.714  132.892        272.722
# 8    coordinate 8  21.714  132.892  25.929  134.861        274.334
# 9    coordinate 9  25.929  134.861  30.833  137.351        321.674
# 10  coordinate 10  30.833  137.351  35.623  139.803        312.231

# %%
Vs_decision.support_decision(230, 15)[1]
# Out:
#        0     1      2
# 0   0.00  4.60  15.00
# 1   4.60  5.06  14.25
# 2   5.06  5.52  13.50
# 3   5.52  5.98  12.75
# 4   5.98  6.44  12.00
# 5   6.44  6.90  11.25
# 6   6.90  7.36  10.50
# 7   7.36  7.82   9.75
# 8   7.82  8.28   9.00
# 9   8.28  8.74   8.25
# 10  8.74  9.20   7.50

# %%
df = voyage.Calculate(data_kapal, 
                      jalur_pelayaran,
                      data_set_gelombang, 
                      start_time
                     )
df
# Out:
#        coordinate    Lat1     Lng1    Lat2     Lng2  Distance (nm)  \
# 0    coordinate 0  -7.203  112.728  -4.611  116.204        259.111
# 1    coordinate 1  -4.611  116.204  -0.814  118.635        269.590
# 2    coordinate 2  -0.814  118.635   2.372  121.715        265.409
# 3    coordinate 3   2.372  121.715   5.081  125.398        273.803
# 4    coordinate 4   5.081  125.398   8.996  127.586        267.740
# 5    coordinate 5   8.996  127.586  13.232  129.281        272.076
# 6    coordinate 6  13.232  129.281  17.497  131.054        274.721
# 7    coordinate 7  17.497  131.054  21.714  132.892        272.722
# 8    coordinate 8  21.714  132.892  25.929  134.861        274.334
# 9    coordinate 9  25.929  134.861  30.833  137.351        321.674
# 10  coordinate 10  30.833  137.351  35.623  139.803        312.231
#
#     Initial speed (knot)  time 0 (hour)  waktu kumulatif 0  wave height (m)  \
# 0                     15         17.289            204.404             0.39
# ...

# %%
df1 = voyage.Calculation(data_kapal, 
                        jalur_pelayaran,
                        data_set_gelombang, 
                        start_time)
df1
# Out:
#        coordinate    Lat1     Lng1    Lat2     Lng2  Distance (nm)  \
# 0    coordinate 0  -7.203  112.728  -4.611  116.204        259.111
# 1    coordinate 1  -4.611  116.204  -0.814  118.635        269.590
# 2    coordinate 2  -0.814  118.635   2.372  121.715        265.409
# 3    coordinate 3   2.372  121.715   5.081  125.398        273.803
# 4    coordinate 4   5.081  125.398   8.996  127.586        267.740
# 5    coordinate 5   8.996  127.586  13.232  129.281        272.076
# 6    coordinate 6  13.232  129.281  17.497  131.054        274.721
# 7    coordinate 7  17.497  131.054  21.714  132.892        272.722
# 8    coordinate 8  21.714  132.892  25.929  134.861        274.334
# 9    coordinate 9  25.929  134.861  30.833  137.351        321.674
# 10  coordinate 10  30.833  137.351  35.623  139.803        312.231
#
#     wave height (m)  wave period  wave direction  heading angle  \
# 0              0.39         4.43          314.72        261.206
# ...

# %%
df2 = voyage.Perbandingan(jalur_pelayaran, data_kapal)
df2
# Out:
#        coordinate    Lat1     Lng1    Lat2     Lng2  Distance (nm)  \
# 0    coordinate 0  -7.203  112.728  -4.611  116.204        259.111
# 1    coordinate 1  -4.611  116.204  -0.814  118.635        269.590
# 2    coordinate 2  -0.814  118.635   2.372  121.715        265.409
# 3    coordinate 3   2.372  121.715   5.081  125.398        273.803
# 4    coordinate 4   5.081  125.398   8.996  127.586        267.740
# 5    coordinate 5   8.996  127.586  13.232  129.281        272.076
# 6    coordinate 6  13.232  129.281  17.497  131.054        274.721
# 7    coordinate 7  17.497  131.054  21.714  132.892        272.722
# 8    coordinate 8  21.714  132.892  25.929  134.861        274.334
# 9    coordinate 9  25.929  134.861  30.833  137.351        321.674
# 10  coordinate 10  30.833  137.351  35.623  139.803        312.231
#
#     speed (knot)  time (hour)  R Calm Water (kN)  Power (kwh)  foc (ton)
# 0             15       17.289            706.264    11245.302     34.024
# ...

# %% [markdown]
# ### Cara Menampilkan Total FOC

# %%
total_foc1 = df1['foc (ton)'].sum(axis=0)
print('Total Fuel Oil Consumption = {:2f} ton'.format(total_foc1))
# Out:
# Total Fuel Oil Consumption = 1260.069828 ton

# %%
total_foc2 = df2['foc (ton)'].sum(axis=0)
print('Total Fuel Oil Consumption = {:2f} ton'.format(total_foc2))
# Out:
# Total Fuel Oil Consumption = 402.252345 ton

# %%
print('Peningkatan konsumsi bahan bakar karena pengaruh gelombang adalah {:2f}%'.format(((total_foc1)/total_foc2)*100))
# Out:
# Peningkatan konsumsi bahan bakar karena pengaruh gelombang adalah 313.253570%

# %%
def graph_foc(data1, data2):
    # Define plot space
    fig, ax = plt.subplots(figsize=(10, 5)) #ini untuk ukuran gambarnya
    x1 = total_foc(data1)[1]
    x2 = total_foc(data2)[1]
    y1 = total_foc(data1)[0]
    y2 = total_foc(data2)[0]
    # Define x and y axes
    ax.plot(x1, y1, color='cyan', label='FOC tanpa pertimbangan gelombang', linewidth=2, linestyle='-', marker='o')  # plot first line
    ax.plot(x2, y2, color='red', label='FOC dengan pertimbangan gelombang', linewidth=2, linestyle='-.', marker='o')  # plot second line
    # Set plot title and axes labels
    ax.set_title("Fuel Oil Consumption", fontsize=15) 
    ax.set_xlabel("distance (nm)", fontsize=12)
    ax.set_ylabel("foc (ton)", fontsize=12) 
    plt.legend()
    plt.show()
    
def total_foc(route):
    list_foc = []
    list_distance = []
    x = 0
    y = 0
    for distance in route['Distance (nm)']:
        x += distance
        list_distance.append(x)
    for foc in route['foc (ton)']:
        y += foc
        list_foc.append(y)
    return list_foc, list_distance

# %%
def graph_resistance(data1, data2):
    # Define plot space
    fig, ax = plt.subplots(figsize=(10, 5)) #ini untuk ukuran gambarnya
    x1 = total_rt(data1)[1]
    x2 = total_rcw(data2)[1]
    y1 = data1['R Total (kN)']
    y2 = data2['R Calm Water (kN)']
    # Define x and y axes
    ax.plot(x1, y1, color='cyan', label='resistance total', linewidth=2, linestyle='-', marker='o')  # plot first line
    ax.plot(x2, y2, color='red', label='resistance calm water', linewidth=2, linestyle='-.', marker='o')  # plot second line
    # Set plot title and axes labels
    ax.set_title("Resistance Total vs Resistance Calm Water", fontsize=15) 
    ax.set_xlabel("distance (nm)", fontsize=12)
    ax.set_ylabel("Resistance", fontsize=12) 
    plt.legend()
    plt.show()
    
def total_rt(route):
    list_rt = []
    list_distance = []
    x = 0
    y = 0
    for distance in route['Distance (nm)']:
        x += distance
        list_distance.append(x)
    for rt in route['R Total (kN)']:
        y += rt
        list_rt.append(y)
    return list_rt, list_distance

def total_rcw(route):
    list_rcw = []
    list_distance = []
    x = 0
    y = 0
    for distance in route['Distance (nm)']:
        x += distance
        list_distance.append(x)
    for rcw in route['R Calm Water (kN)']:
        y += rcw
        list_rcw.append(y)
    return list_rcw, list_distance

# %%
graph_foc(df1, df2)

# %%
graph_resistance(df1, df2)

# %%
import RAW
RAW.wave_data(0.28, 2.45)
# Out:
# (0.4592, 30.77714968152867, 12.562101910828028)

# %%
###WaveData.save_excel(coordinate_data= 'Jalur Pelayaran.xlsx',
                     ###nama_file= '28 November 2022.xlsx')

# %%
import WaveData
WaveData.save_excel(coordinate_data= 'Jalur Pelayaran.xlsx',
                    nama_file= '11 Desember 2022.xlsx')
# Out:
#      coordinate 0 Wave Height  coordinate 0 Wave Direction  \
# 0                        0.12                       269.99
# 1                        0.12                       271.50
# 2                        0.12                       273.00
# 3                        0.12                       274.51
# 4                        0.12                       276.06
# ..                        ...                          ...
# 236                       NaN                          NaN
# 237                       NaN                          NaN
# 238                       NaN                          NaN
# 239                       NaN                          NaN
# 240                       NaN                          NaN
#
#      coordinate 0 Wave Period  coordinate 1 Wave Height  \
# 0                        2.18                      0.10
# 1                        2.17                      0.11
# 2                        2.16                      0.11
# ...
